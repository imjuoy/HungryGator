# %%
import matplotlib.pyplot as plt
from matplotlib import interactive
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import pandas as pd

# %%
df= pd.read_excel("../DataFiles/Project_prototype_datafiles.xlsx",sheet_name="MergedData")
df["Zip"]= df["Zip"].astype(str)
df["Rating"]= pd.to_numeric(df["Rating"],errors="coerce")

# %%
group_df = df.groupby(['Zip','Source'])['Rating','Votes'].mean()
group_df= pd.DataFrame(group_df, index=None).reset_index()

fig = sns.barplot(x='Source',y='Votes',data=group_df[group_df.Zip =="33127.0"])
fig.set_title('Distribution of Votes')
fig.set_xlabel('Source')
fig.set_ylabel('Average Votes')
fig.grid(b='off')
plt.show()

# %%
fig = sns.barplot(x='Source',y='Rating',data=group_df[group_df.Zip =="33127.0"])
fig.set_title('Distribution of Rating')
fig.set_xlabel('Source')
fig.set_ylabel('Average Rating')
fig.grid(b='off')
plt.show()

# %%
group_df
# Out:
#          Zip       Source    Rating        Votes
# 0    11696.0  TripAdvisor       NaN          NaN
# 1    33004.0       Zomato  4.700000   731.000000
# 2    33010.0         Yelp  4.500000   473.000000
# 3    33012.0  TripAdvisor       NaN          NaN
# 4    33014.0       Zomato  4.200000   487.000000
# 5    33015.0  TripAdvisor       NaN     3.000000
# 6    33016.0  TripAdvisor       NaN     1.500000
# 7    33019.0       Zomato  3.900000   623.000000
# 8    33024.0  TripAdvisor       NaN     1.000000
# 9    33025.0       Zomato  4.200000   329.000000
# 10   33028.0       Zomato  4.400000   673.000000
# 11   33029.0       Zomato  4.500000   348.000000
# 12   33033.0  TripAdvisor       NaN          NaN
# 13   33054.0  TripAdvisor       NaN          NaN
# 14   33071.0       Zomato  4.500000   762.000000
# 15   33076.0       Zomato  4.700000   900.000000
# 16   33101.0         Yelp  4.500000    38.000000
# 17   33122.0  TripAdvisor       NaN     1.000000
# 18   33122.0         Yelp  4.300000   199.200000
# 19   33125.0  TripAdvisor       NaN    11.250000
# 20   33125.0         Yelp  3.900000   161.000000
# 21   33126.0  TripAdvisor       NaN    29.352941
# 22   33126.0         Yelp  4.000000   149.000000
# 23   33127.0  TripAdvisor       NaN    32.000000
# 24   33127.0         Yelp  4.026316   307.947368
# 25   33127.0       Zomato  4.200000   491.000000
# 26   33128.0  TripAdvisor       NaN     2.000000
# 27   33128.0         Yelp  3.954545   262.636364
# 28   33128.0       Zomato  3.800000   348.000000
# 29   33129.0  TripAdvisor       NaN     4.600000
# ..       ...          ...       ...          ...
# 120  33184.0         Yelp  4.416667    49.833333
# 121  33185.0  TripAdvisor       NaN     1.000000
# 122  33186.0  TripAdvisor       NaN    10.333333
# 123  33186.0         Yelp  3.952381   174.000000
# 124  33186.0       Zomato  4.500000  1345.000000
# 125  33189.0  TripAdvisor       NaN          NaN
# 126  33193.0  TripAdvisor       NaN     1.000000
# 127  33196.0  TripAdvisor       NaN     6.000000
# 128  33196.0         Yelp  4.500000    61.000000
# 129  33196.0       Zomato  4.400000  1048.000000
# 130  33231.0         Yelp  4.000000   133.000000
# 131  33255.0         Yelp  4.000000    40.000000
# 132  33256.0         Yelp  4.000000   344.000000
# 133  33301.0       Zomato  4.166667   624.666667
# 134  33304.0       Zomato  4.250000   512.333333
# 135  33305.0       Zomato  4.500000   948.000000
# 136  33308.0       Zomato  4.000000   392.000000
# 137  33312.0       Zomato  4.400000   809.000000
# 138  33316.0       Zomato  4.260000   605.000000
# 139  33351.0       Zomato  4.100000   302.000000
# 140  33401.0       Zomato  3.900000   623.000000
# 141  33410.0       Zomato  4.300000   606.000000
# 142  33431.0       Zomato  4.200000  1003.000000
# 143  33432.0       Zomato  4.200000   342.000000
# 144  33434.0       Zomato  3.700000   184.000000
# 145  33441.0       Zomato  4.500000   825.000000
# 146  33444.0       Zomato  3.900000   600.500000
# 147  33458.0       Zomato  4.600000   430.000000
# 148  33477.0       Zomato  4.566667   763.666667
# 149      nan  TripAdvisor       NaN    13.289474
#
# [150 rows x 4 columns]
